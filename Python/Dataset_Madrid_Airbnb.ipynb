# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.10/dist-packages (4.19.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from selenium) (4.10.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.6)
# Requirement already satisfied: outcome in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.10/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# all imports
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

import json
import time

import pandas as pd

from multiprocessing import Pool

import os

# %%
airbnb_url = 'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click'

# %%
soup = BeautifulSoup(requests.get(airbnb_url).content, 'html.parser')

# %%
listings = soup.find_all('div', 'cy5jw6o')

# %%
# First Generation :)
def extract_basic_features(listing_html):
    features_dict = {}


    name = listing_html.find("div", {"class": "t1jojoys"}).get_text()
    header = listing_html.find("div", {"class": "fb4nyux"}).get_text()
    url = listing_html.find('a').get('href')


    features_dict['name'] = name
    features_dict['header'] = header
    features_dict['url'] = url

    return features_dict

# %%
extract_basic_features(listings[0])
# Out:
# {'name': 'Apartamento en Centro Madrid',
#  'header': 'Alojamiento entero en el centro de Madrid',
#  'url': '/rooms/1120220796513899602?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-11&check_out=2024-05-16&source_impression_id=p3_1711642001_vhtsToNCbc8IBTCs&previous_page_section_name=1000&federated_search_id=5b410bee-8669-42b2-b849-42bce544f195'}

# %%
# too many separate extractions
RULES_SEARCH_PAGE = {
    'url': {'tag': 'a', 'get': 'href'},
    'name': {'tag': 'div', 'class': 't1jojoys'},
    'header': {'tag': 'span', 'class': 't6mzqp7'},
    'rating_n_reviews': {'tag': 'span', 'class': 'ru0q88m'},
    'price': {'tag': 'span', 'class': 'a8jt5op'},
    'superhost': {'tag': 'span', 'class': 'dir dir-ltr'},
}

# %%
def extract_element(listing_html, params):
    # 1. Find the right tag
    if 'class' in params:
        elements_found = listing_html.find_all(params['tag'], params['class'])
    else:
        elements_found = listing_html.find_all(params['tag'])

    # 2. Extract the right element
    tag_order = params.get('order', 0)
    element = elements_found[tag_order]

    # 3. Get text
    if 'get' in params:
        output = element.get(params['get'])
    else:
        output = element.get_text()

    return output

# %%
print(extract_element(listings[13], RULES_SEARCH_PAGE['header']))
print(extract_element(listings[13], RULES_SEARCH_PAGE['url']))
print(extract_element(listings[13], RULES_SEARCH_PAGE['name']))
print(extract_element(listings[13], RULES_SEARCH_PAGE['rating_n_reviews']))
print(extract_element(listings[13], RULES_SEARCH_PAGE['price']))
print(extract_element(listings[13], RULES_SEARCH_PAGE['superhost']))
# Out:
# PUERTA DEL SOL, ESTUDIO LUMINOSO, DISEÑO Y BALCÓN
# /rooms/16872465?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-12-15&check_out=2024-12-20&source_impression_id=p3_1711642001_HSGxHnoVxincOgc7&previous_page_section_name=1000&federated_search_id=5b410bee-8669-42b2-b849-42bce544f195
# Apartamento en Centro Madrid
# 4,96 (494)
# Recomendación del viajero
# Anfitrión particular

# %%
# for feature in RULES_SEARCH_PAGE:
 #   print(f"{feature}: {extract_element(listings[13], RULES_SEARCH_PAGE[feature])}")

# %%
for feature in RULES_SEARCH_PAGE:
    try:
        print(f"{feature}: {extract_element(listings[0], RULES_SEARCH_PAGE[feature])}")
    except:
        print(f"{feature}: empty")
# Out:
# url: /rooms/1120220796513899602?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-11&check_out=2024-05-16&source_impression_id=p3_1711642001_vhtsToNCbc8IBTCs&previous_page_section_name=1000&federated_search_id=5b410bee-8669-42b2-b849-42bce544f195
# name: Apartamento en Centro Madrid
# header: Alojamiento entero en el centro de Madrid
# rating_n_reviews: Nuevo
# price: Anfitrión particular
# superhost: Anfitrión particular

# %%
airbnb_url
# Out:
# 'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click'

# %%
# let's finally write this function
def get_listings(search_page):
    soup = BeautifulSoup(requests.get(search_page).content, 'html.parser')
    listings = soup.find_all('div', 'cy5jw6o')

    return listings

# %%
# it works
len(get_listings(airbnb_url))
# Out:
# 18

# %%
# let's try next page
new_url = airbnb_url + '&items_offset=20'
len(get_listings(new_url))
# Out:
# 18

# %%
# checking the content, if the data is there
print(extract_element(get_listings(airbnb_url)[0], RULES_SEARCH_PAGE['name']))
print(extract_element(get_listings(new_url)[0], RULES_SEARCH_PAGE['name']))
# Out:
# Apartamento en Centro Madrid
# Loft en Centro Madrid

# %%
# let's iterate through all 15 pages
all_listings = []
for i in range(15):
    offset = 20 * i
    new_url = airbnb_url + f'&items_offset={offset}'
    new_listings = get_listings(new_url)
    all_listings.extend(new_listings)

    # let's check if it's scraping
    print(len(all_listings))
# Out:
# 18
# 36
# 54
# 72
# 90
# 108
# 126
# 144
# 162
# 180
# 198
# 216
# 234
# 252
# 270

# %%
# why? maybe Airbnb tries to prevent scraping
# let's wait a couple of seconds after every iteration
import time

all_listings = []
for i in range(15):
    offset = 20 * i
    new_url = airbnb_url + f'&items_offset={offset}&section_offset=3'
    new_listings = get_listings(new_url)
    all_listings.extend(new_listings)

    # let's check if it's scraping
    print(len(all_listings))

    time.sleep(2)
# Out:
# 18
# 36
# 54
# 72
# 90
# 108
# 126
# 144
# 162
# 180
# 198
# 216
# 234
# 252
# 270

# %%
# another random check, if the data is there
print(extract_element(all_listings[113], RULES_SEARCH_PAGE['name']))
# Out:
# Loft en Salamanca

# %%
# 1. build all urls
def build_urls(main_url, listings_per_page=20, pages_per_location=15):
    url_list = []
    for i in range(pages_per_location):
        offset = listings_per_page * i
        url_pagination = main_url + f'&items_offset={offset}'
        url_list.append(url_pagination)

    return url_list

# %%
# build a list of URLs
url_list = build_urls(airbnb_url)

# %%
url_list
# Out:
# ['https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=0',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=20',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=40',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=60',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=80',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=100',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=120',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=140',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=160',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=180',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=200',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=220',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=240',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=260',
#  'https://www.airbnb.es/s/Madrid--Espa%C3%B1a/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-02-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Madrid&place_id=ChIJgTwKgJcpQg0RaSKMYcHeNsQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click&items_offset=280']

# %%
# safe function to extract all features from one page
def extract_page_features(soup, rules):
    features_dict = {}
    for feature in rules:
        try:
            features_dict[feature] = extract_element(soup, rules[feature])
        except:
            features_dict[feature] = 'empty'

    return features_dict

# %%
extract_page_features(listings[0], RULES_SEARCH_PAGE)
# Out:
# {'url': '/rooms/1120220796513899602?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-11&check_out=2024-05-16&source_impression_id=p3_1711642001_vhtsToNCbc8IBTCs&previous_page_section_name=1000&federated_search_id=5b410bee-8669-42b2-b849-42bce544f195',
#  'name': 'Apartamento en Centro Madrid',
#  'header': 'Alojamiento entero en el centro de Madrid',
#  'rating_n_reviews': 'Nuevo',
#  'price': 'Anfitrión particular',
#  'superhost': 'Anfitrión particular'}

# %%
# 2. Iteratively scrape pages
def process_search_pages(url_list):
    features_list = []
    for page in url_list:
        listings = get_listings(page)
        for listing in listings:
            features = extract_page_features(listing, RULES_SEARCH_PAGE)
            features_list.append(features)

    return features_list

# %%
# try for one page
base_features = process_search_pages(url_list)

# %%
base_features
# Out:
# [{'url': '/rooms/46416127?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-11&check_out=2024-04-16&source_impression_id=p3_1711642076_guK%2FG%2FWzhAw1901a&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Habitación compartida en Centro Madrid',
#   'header': 'Madrid Centro: Puerta del Sol, Tirso de Molina',
#   'rating_n_reviews': '4,95 (83)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/1120220796513899602?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-11&check_out=2024-05-16&source_impression_id=p3_1711642076_Kd3%2FENtX4B3eX4YA&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Alojamiento entero en el centro de Madrid',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/1019679548854540460?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-18&check_out=2024-05-23&source_impression_id=p3_1711642076_s%2BzgDsCT3G98XFSo&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Alojamiento en Centro Madrid',
#   'header': 'Habitación céntrica en Chamberí',
#   'rating_n_reviews': '4,74 (23)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/1120093500114698390?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-07&check_out=2024-04-12&source_impression_id=p3_1711642076_jI%2FFFPdP%2F52Dygnp&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'GuestReady - Madrid Urban Retreat',
#   'rating_n_reviews': 'Nuevo',
#   'price': '3 camas «queen»',
#   'superhost': '3 camas «queen»'},
#  {'url': '/rooms/1119750870732308638?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-07&check_out=2024-04-12&source_impression_id=p3_1711642076_8kdwI7iP9FbpvfWc&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Patio de La Latina',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/999773251029788413?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2025-02-24&check_out=2025-03-03&source_impression_id=p3_1711642076_qGb8a9teiFCNo7Bs&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Diversión Urbana junto a Gran Vía',
#   'rating_n_reviews': '4,8 (25)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/567301424368343959?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642076_QS0mK8CH%2B5DA7SCk&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Tetuán',
#   'header': 'Apto Estandar',
#   'rating_n_reviews': '4,83 (593)',
#   'price': 'Superanfitrión',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/1069270302374275030?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-31&check_out=2024-08-05&source_impression_id=p3_1711642076_O541%2BAcriGdzeVHU&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Piso dos habitaciones Gran Vía',
#   'rating_n_reviews': '5,0 (13)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/36073263?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-06&check_out=2024-04-11&source_impression_id=p3_1711642076_fsCiZrJONYlNW2OA&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Bonito apartamento en Las Letras y Museo del Prado',
#   'rating_n_reviews': '4,66 (140)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/1112961336426676973?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-14&check_out=2024-04-19&source_impression_id=p3_1711642076_y6zykiUW60AouZMF&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'GuestReady -Marvelous Retreat near Plaza de España',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/1096887199814770601?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-14&check_out=2024-04-19&source_impression_id=p3_1711642076_QgM%2FiFwagbaGxwiP&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Chamartín',
#   'header': 'Amplio piso nuevo cerca del Estadio Bernabéu #2',
#   'rating_n_reviews': '5,0 (3)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/837663235542711479?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642076_UykHICA8fn43pz7n&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Chamartín',
#   'header': 'Loft acogedor en zona de Avenida de América Madrid',
#   'rating_n_reviews': '4,85 (40)',
#   'price': 'Superanfitrión',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/53375014?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-07&check_out=2024-04-12&source_impression_id=p3_1711642076_hQo1vGfPBDv2TWxv&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Salamanca',
#   'header': 'Glamuroso Piso Junto a Puerta de Alcalá - Madrid',
#   'rating_n_reviews': '4,85 (142)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/16872465?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-12-15&check_out=2024-12-20&source_impression_id=p3_1711642076_1S5pUgnR73zmNL9o&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'PUERTA DEL SOL, ESTUDIO LUMINOSO, DISEÑO Y BALCÓN',
#   'rating_n_reviews': '4,96 (494)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/656836517078760380?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-23&check_out=2024-06-28&source_impression_id=p3_1711642076_dWt4cWXizndzAr7W&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Loft en Centro Madrid',
#   'header': 'Acogedor Apartamento en Malasaña',
#   'rating_n_reviews': '4,72 (43)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/1107827657757590531?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-14&check_out=2024-07-19&source_impression_id=p3_1711642076_92D3bmXCXHD%2FqGFw&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Retiro',
#   'header': 'Apartamento en el centro de Retiro',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/1109219606159297788?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-02&check_out=2024-06-07&source_impression_id=p3_1711642076_a62FsoXSolyQ9M%2Fz&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Arganzuela',
#   'header': 'Exquisito estudio en el centro',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/645352260145108648?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642076_qVFmQQWErF%2FudC6m&previous_page_section_name=1000&federated_search_id=1cd3a62c-ca4b-440d-9b0b-59ddc53367c1',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'D-CityCentre-La Latina-WiFi-A/C',
#   'rating_n_reviews': '4,87 (193)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/36511647?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-23&check_out=2024-06-28&source_impression_id=p3_1711642077_Rc44NJkMYewJY%2B7D&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Apartamento en Madrid',
#   'header': 'APART. EXP C - CENTRO MADRID,  2PERS!  INTERIOR',
#   'rating_n_reviews': '4,56 (208)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/701211230857023746?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1569153250&check_in=2024-06-03&check_out=2024-06-08&source_impression_id=p3_1711642077_wSrnwrnhZt501S8j&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Habitación en Madrid',
#   'header': 'Acogedor dormitorio junto a Latina',
#   'rating_n_reviews': '4,74 (72)',
#   'price': 'Quédate con Zoraida',
#   'superhost': 'Quédate con Zoraida'},
#  {'url': '/rooms/599111693828320997?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-07&check_out=2024-07-12&source_impression_id=p3_1711642077_vRtKnhp07ZN%2BSwbn&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Apartamento en Madrid',
#   'header': 'Acogedor apartamento en pleno centro, en Lavapiés.',
#   'rating_n_reviews': '4,48 (54)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/51435904?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-09&check_out=2024-06-14&source_impression_id=p3_1711642077_iIEkLmY6jJpxCrFj&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Apartamento en Madrid',
#   'header': 'Estudio Antón Martín, 20 m2 , sofá cama,',
#   'rating_n_reviews': '4,8 (155)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/26002097?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-22&check_out=2024-07-27&source_impression_id=p3_1711642077_p6kzFUZGfMc6o5CX&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Apartamento en Madrid',
#   'header': 'URBAN CHIC LAVAPIES | WIFI - A/C',
#   'rating_n_reviews': '4,68 (258)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/817914867114504764?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1579701496&check_in=2024-06-01&check_out=2024-06-06&source_impression_id=p3_1711642077_rUuD2vbrfEWPtVmB&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Habitación en Madrid',
#   'header': 'Pequeña habitación privada',
#   'rating_n_reviews': '4,91 (75)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Quédate con Bartolomé'},
#  {'url': '/rooms/34812107?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-14&check_out=2024-07-19&source_impression_id=p3_1711642077_4k2JWhcNcdDBw0aS&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Apartamento en Madrid',
#   'header': 'Apartamento en Madrid Centro, la mejor ubicación!',
#   'rating_n_reviews': '4,79 (191)',
#   'price': 'Superanfitrión',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/32133730?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-07&check_out=2024-04-12&source_impression_id=p3_1711642077_ccUWoTUkTMbOKOdX&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Loft en Madrid',
#   'header': 'Loft Amplio,Independiente, WiFi, Zona Aparcamiento',
#   'rating_n_reviews': '4,7 (268)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/43599314?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1215116658&check_in=2024-04-07&check_out=2024-04-12&source_impression_id=p3_1711642077_%2FtullvGo66z78pWe&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Habitación en Getafe',
#   'header': 'Habitación Privada en Getafe. \nJuan de la Cierva',
#   'rating_n_reviews': '4,88 (56)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Quédate con Olga'},
#  {'url': '/rooms/759998222797381557?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-12&check_out=2024-05-17&source_impression_id=p3_1711642077_mthtwAxZMscmK1lv&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Apartamento en Madrid',
#   'header': 'Con House Malasaña Studio I en Madrid',
#   'rating_n_reviews': '4,5 (40)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/30060769?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=619297166&check_in=2024-05-10&check_out=2024-05-15&source_impression_id=p3_1711642077_h5EexXOpISldBzX0&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Habitación en Madrid',
#   'header': 'Habitación agradable bien comunicada con el centro',
#   'rating_n_reviews': '4,91 (173)',
#   'price': 'Superanfitrión',
#   'superhost': 'Quédate con Eduardo'},
#  {'url': '/rooms/665030229478277403?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-24&check_out=2024-06-29&source_impression_id=p3_1711642077_eZN8Z7yNJ%2BsMKzCj&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Apartamento en Madrid',
#   'header': 'Estudio coqueto en el barrio de Salamanca',
#   'rating_n_reviews': '5,0 (11)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/53055878?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-23&check_out=2024-06-30&source_impression_id=p3_1711642077_WtLMs89ALvO8wQ3s&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Apartamento en Madrid',
#   'header': 'El piso de Aurelia',
#   'rating_n_reviews': '4,89 (73)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/25939631?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-08-01&check_out=2024-08-06&source_impression_id=p3_1711642077_ZrQwWyC3%2BthOsaK9&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Apartamento en Madrid',
#   'header': 'Estudio interior - Pacífico - Aeropuerto Exprés',
#   'rating_n_reviews': '4,75 (318)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/13707810?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-03&check_out=2024-06-08&source_impression_id=p3_1711642077_BdZJln0Jw46wmzuI&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Apartamento en Madrid',
#   'header': 'APARTAMENTO COMPLETO. LAVAPIAS, AIRE ACONDICIONADO.',
#   'rating_n_reviews': '4,5 (270)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/10993059?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-19&check_out=2024-06-24&source_impression_id=p3_1711642077_w5ht8XyjPmkd4Q3b&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Apartamento en Madrid',
#   'header': 'Estudio completo: PEQUEÑA LUNA AZUL',
#   'rating_n_reviews': '4,72 (288)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/12304349?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-08-06&check_out=2024-08-11&source_impression_id=p3_1711642077_CUrpQcizTnR%2Fjh1S&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Apartamento en Madrid',
#   'header': 'Piso con Encanto Parque del Retiro',
#   'rating_n_reviews': '4,74 (91)',
#   'price': 'Superanfitrión',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/18985326?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=328160890&check_in=2024-04-11&check_out=2024-04-16&source_impression_id=p3_1711642077_jlPnnCuMfDse4jIV&previous_page_section_name=1000&federated_search_id=2f1b458a-8ac8-4039-b200-f667dc6d16ef',
#   'name': 'Habitación en Madrid',
#   'header': 'Habitación Privada en Precioso Apartamento Madrid',
#   'rating_n_reviews': '4,89 (72)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Quédate con Jesus'},
#  {'url': '/rooms/2711470?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-14&check_out=2024-07-19&source_impression_id=p3_1711642079_S2fNW4UqVdJFgqWj&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'GRAN VIA III',
#   'rating_n_reviews': '4,48 (93)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/897019606791123054?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-27&check_out=2024-08-01&source_impression_id=p3_1711642079_e58AkrxtMm4zdwph&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en Arganzuela',
#   'header': 'Piso Acogedor Cerca de Atocha',
#   'rating_n_reviews': '4,8 (5)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/1102155686095438299?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-28&check_out=2024-08-02&source_impression_id=p3_1711642079_svRYd56TAtI114Rw&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Nuevo apartamento+patio Chueca Zerolo GVia',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/28130302?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-16&check_out=2024-06-21&source_impression_id=p3_1711642079_UuHj0Jfl7zQeQkpy&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en Salamanca',
#   'header': 'Piso en el centro de Madrid en Barrio Salamanca',
#   'rating_n_reviews': '4,75 (75)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/22373063?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-30&check_out=2024-08-04&source_impression_id=p3_1711642079_RcSJAlgvtkLHLgvq&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en Centro Madrid',
#   'header': '¡La mejor ubicación! ¡Lindo! ¡Balcón con vistas! WIFI.',
#   'rating_n_reviews': '4,52 (344)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/1110797398896009176?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-14&check_out=2024-04-19&source_impression_id=p3_1711642079_3votHrTUUkf8gIg%2B&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Loft en Puente de Vallecas',
#   'header': 'Suite privada con entrada independiente',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/1101588224651543470?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-07&check_out=2024-04-12&source_impression_id=p3_1711642079_xrPU6AAb%2BUZKVt3R&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en Salamanca',
#   'header': 'Refugio Manuel Becerra',
#   'rating_n_reviews': '4,5 (4)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/20129330?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1141643852&check_in=2024-04-04&check_out=2024-04-11&source_impression_id=p3_1711642079_J6SEaEzeFAlG%2FTbB&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Habitación en Ibiza',
#   'header': 'Acogedora habitacion Parque El Retiro',
#   'rating_n_reviews': '4,83 (109)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Quédate con Betty'},
#  {'url': '/rooms/909881241219973792?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642079_ZnAoYy5tGKGIqHfY&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Habitación de hotel compartida en Barajas',
#   'header': 'Hostelfly. Cama en Habitación mixta 10 pax',
#   'rating_n_reviews': '4,65 (171)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/1019679548854540460?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-18&check_out=2024-05-23&source_impression_id=p3_1711642079_0Go3D01PkO33yWaE&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Alojamiento en Centro Madrid',
#   'header': 'Habitación céntrica en Chamberí',
#   'rating_n_reviews': '4,74 (23)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/776006859289639478?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-14&check_out=2024-04-19&source_impression_id=p3_1711642079_zp5%2BAKWrTMQII8GK&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en San Blas',
#   'header': 'Aeropuerto turismo',
#   'rating_n_reviews': '4,55 (64)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/27199836?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-09-09&check_out=2024-09-14&source_impression_id=p3_1711642079_IKwxjWnpbKLC8jCC&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Cómodo piso Estudio cerca metro Gran Vía Madrid',
#   'rating_n_reviews': '4,64 (379)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/952118145352980010?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-12&check_out=2024-05-17&source_impression_id=p3_1711642079_9l5nItydbOATabqj&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en Tetuán',
#   'header': 'Acogedor piso en el centro de Madrid.',
#   'rating_n_reviews': '4,46 (57)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/693411803528513755?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-07&check_out=2024-04-12&source_impression_id=p3_1711642079_ju%2BQKJtpt5I0ENw4&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Apartamento en Malasaña, en el centro de Madrid',
#   'rating_n_reviews': '4,72 (43)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/741295930101134488?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-08&check_out=2024-04-13&source_impression_id=p3_1711642079_Pkvj0KeoGQgZ9ue2&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Precioso y luminoso. Malasaña.',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/45273360?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-16&check_out=2024-06-21&source_impression_id=p3_1711642079_9C91pC7Z%2FcucJ3C7&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en Centro Madrid',
#   'header': '"Hermoso loft" en el corazón de Madrid',
#   'rating_n_reviews': '4,59 (169)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/1087582223016163702?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1864590857&check_in=2024-05-05&check_out=2024-05-10&source_impression_id=p3_1711642079_2jzrPgSTYYmZSVhm&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Habitación en Centro Madrid',
#   'header': 'Guets Room sin ventana',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Quédate con Christian Y Sebastian',
#   'superhost': 'Quédate con Christian Y Sebastian'},
#  {'url': '/rooms/25939631?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-08-01&check_out=2024-08-06&source_impression_id=p3_1711642079_4QOXKVD5j8YOagUP&previous_page_section_name=1000&federated_search_id=a2d263b0-5b57-4263-a42e-0c308ca0e210',
#   'name': 'Apartamento en Retiro',
#   'header': 'Estudio interior - Pacífico - Aeropuerto Exprés',
#   'rating_n_reviews': '4,75 (318)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/21389483?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-08-12&check_out=2024-08-17&source_impression_id=p3_1711642080_7p4O28oGuUKtUAYV&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Apartamento en Atocha',
#   'header': 'Apartamento de Lujo - Retiro-Atocha. Wifi, AC*',
#   'rating_n_reviews': '4,91 (596)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/37444466?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1304714108&check_in=2024-05-07&check_out=2024-05-12&source_impression_id=p3_1711642080_7EQh2n3NpwI73nTd&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Habitación en Puente de Vallecas',
#   'header': 'Habitación centrica con terraza & desayuno',
#   'rating_n_reviews': '4,93 (136)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Quédate con Alecsa'},
#  {'url': '/rooms/38863726?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-08&check_out=2024-05-13&source_impression_id=p3_1711642080_%2BepU3NMtfENOV4Eg&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Apartamento en Chamartín',
#   'header': 'Precioso apartamento en un barrio exclusivo',
#   'rating_n_reviews': '4,86 (107)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/46718626?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-11-16&check_out=2024-11-21&source_impression_id=p3_1711642080_%2FDS6Ax3t%2BU2PCVYM&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Apartamento en Centro Madrid',
#   'header': '< < < < Centre-Live-In-Atocha-WIFI A/C > > >',
#   'rating_n_reviews': '4,84 (276)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/46724279?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-11-13&check_out=2024-11-18&source_impression_id=p3_1711642080_sgiBwrzmO7UI03Mv&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Apartamento en Centro Madrid',
#   'header': '< < < Centre-Live-In-Atocha-WIFI A/C > >',
#   'rating_n_reviews': '4,9 (292)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/934091390778108619?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-30&check_out=2024-07-05&source_impression_id=p3_1711642080_8Y4%2Fd26GCxqBqoUy&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Apartamento Plaza España',
#   'rating_n_reviews': '4,95 (19)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/859231715384577892?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1617984808&check_in=2024-04-28&check_out=2024-05-03&source_impression_id=p3_1711642080_rKOUmfJ0ovPWTglZ&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Habitación en Tetuán',
#   'header': 'Cómoda habitación cerca del centro de madrid',
#   'rating_n_reviews': '4,81 (81)',
#   'price': 'Superanfitrión',
#   'superhost': 'Quédate con Vivi'},
#  {'url': '/rooms/1026128264721243793?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-23&check_out=2024-06-28&source_impression_id=p3_1711642080_QmT6j7dWArShfN62&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Apartamento en Gran Via C',
#   'rating_n_reviews': '4,7 (23)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/553689050829534700?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642080_8l7%2FteNYCY9VtpMz&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Hermoso piso apartamento en el corazón ♥️ de Madrid',
#   'rating_n_reviews': '4,75 (271)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/739694298034281287?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1642409380&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642080_MpVUD08YWlFzw%2Bn7&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Habitación en Hortaleza',
#   'header': 'Habitación con baño, metro y parking Gratis',
#   'rating_n_reviews': '4,97 (32)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Quédate con Mercedes'},
#  {'url': '/rooms/1016441089314560630?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-02&check_out=2024-04-07&source_impression_id=p3_1711642080_JZV23gruypZTJEXb&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Apartamento en Chamartín',
#   'header': 'Tranquilo loft en Bernabéu',
#   'rating_n_reviews': '4,83 (24)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/1101588224651543470?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-07&check_out=2024-04-12&source_impression_id=p3_1711642080_dEmaUm34kL8dotiB&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Apartamento en Salamanca',
#   'header': 'Refugio Manuel Becerra',
#   'rating_n_reviews': '4,5 (4)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/39815062?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1106111142&check_in=2024-04-07&check_out=2024-04-12&source_impression_id=p3_1711642080_MDkGX2PSt1cXnOA0&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Habitación en Barajas',
#   'header': 'Habitación individual Alameda de Osuna (Madrid)',
#   'rating_n_reviews': '4,64 (340)',
#   'price': 'Quédate con Juan Carlos',
#   'superhost': 'Quédate con Juan Carlos'},
#  {'url': '/rooms/599899841714156736?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642080_%2FGVcxVE%2BSd7GBIQx&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Hotel boutique en Argüelles',
#   'header': 'Marco Polo Hostal Boutique Habitación Indiv Deluxe',
#   'rating_n_reviews': '4,82 (85)',
#   'price': 'Superanfitrión',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/27978869?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-08-20&check_out=2024-08-25&source_impression_id=p3_1711642080_8uFNlkq%2FGhA5EHV%2F&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Apto. residencial en Centro Madrid',
#   'header': 'Apartamento recién renovado en el centro de Madrid',
#   'rating_n_reviews': '4,71 (200)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/918008925316221139?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-02&check_out=2024-06-07&source_impression_id=p3_1711642080_z2vcSwnOFE5EvM3j&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'El industrial de la The The The',
#   'rating_n_reviews': '4,78 (54)',
#   'price': 'Superanfitrión',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/701211230857023746?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1569153250&check_in=2024-06-03&check_out=2024-06-08&source_impression_id=p3_1711642080_VwCHwG6pVqzSTlr%2B&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Habitación en Latina',
#   'header': 'Acogedor dormitorio junto a Latina',
#   'rating_n_reviews': '4,74 (72)',
#   'price': 'Quédate con Zoraida',
#   'superhost': 'Quédate con Zoraida'},
#  {'url': '/rooms/1107827657757590531?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-14&check_out=2024-07-19&source_impression_id=p3_1711642080_D2mBs8ZRzJw704Fb&previous_page_section_name=1000&federated_search_id=fedbc020-d9bc-4034-8233-536b7827cd10',
#   'name': 'Apartamento en Retiro',
#   'header': 'Apartamento en el centro de Retiro',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/1001199075060916360?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-19&check_out=2024-05-24&source_impression_id=p3_1711642081_KmRdSnNQQxExq%2Bow&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Deluxe apartment in Malasaña',
#   'rating_n_reviews': '4,79 (24)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/36511647?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-23&check_out=2024-06-28&source_impression_id=p3_1711642081_3vP9miaE6s3botKk&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'APART. EXP C - CENTRO MADRID,  2PERS!  INTERIOR',
#   'rating_n_reviews': '4,56 (208)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/45273360?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-16&check_out=2024-06-21&source_impression_id=p3_1711642081_VMUf8TFMdQA%2Fh9rB&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Centro Madrid',
#   'header': '"Hermoso loft" en el corazón de Madrid',
#   'rating_n_reviews': '4,59 (169)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/873714419248836292?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1632464412&check_in=2024-04-05&check_out=2024-04-10&source_impression_id=p3_1711642081_nKeDyUw9wn9HSU%2Bm&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Habitación en Centro Madrid',
#   'header': 'Habitación Nubes de Algodón',
#   'rating_n_reviews': '4,52 (61)',
#   'price': 'Quédate con Maria',
#   'superhost': 'Quédate con Maria'},
#  {'url': '/rooms/1302691?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-03&check_out=2024-04-08&source_impression_id=p3_1711642081_yd8i1eBpY7HwV%2B9Y&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Acogedor y Céntrico Apartamento en Gran Vía | A005',
#   'rating_n_reviews': '4,31 (600)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/1118571282241364285?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1867182070&check_in=2024-05-23&check_out=2024-05-28&source_impression_id=p3_1711642081_5tKwAXhC2mGtCdPe&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Habitación en Centro Madrid',
#   'header': 'Single Rm (Anton Martin)',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Quédate con Mario',
#   'superhost': 'Quédate con Mario'},
#  {'url': '/rooms/51647382?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1241556904&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642081_zwaWH9EpZl%2Bl1REG&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Habitación en Puente de Vallecas',
#   'header': 'Buenos Aires en Madrid',
#   'rating_n_reviews': '4,68 (161)',
#   'price': 'Quédate con Norma',
#   'superhost': 'Quédate con Norma'},
#  {'url': '/rooms/1120208388747899462?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-21&check_out=2024-04-26&source_impression_id=p3_1711642081_PJQ9eG8XkdhpIih%2B&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Apartamento céntrico con terraza',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/781136669307953842?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1546150353&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642081_cH7Z2sGcZ9caxchq&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Habitación en Centro Madrid',
#   'header': 'Suite Balcón de los Poetas',
#   'rating_n_reviews': '4,39 (59)',
#   'price': 'Quédate con Maria',
#   'superhost': 'Quédate con Maria'},
#  {'url': '/rooms/1097059151603654718?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-28&check_out=2024-08-02&source_impression_id=p3_1711642081_9LL8i0ltEfsX7HwM&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Centro Madrid',
#   'header': '4. Bajo coste: apartamento de 2 dormitorios y 1 baño',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/983410?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-29&check_out=2024-05-04&source_impression_id=p3_1711642081_dPpCj2nWDH8vlFoY&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Tetuán',
#   'header': 'Castellana,vistas***** WiFi, ADSL',
#   'rating_n_reviews': '4,64 (532)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/960923253089433400?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642081_Cue%2Ba8sh1gzXoczX&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Tetuán',
#   'header': 'Cerca de Bernabeu Court, moderno estudio con aire acondicionado y ascensor.',
#   'rating_n_reviews': '4,56 (25)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/1052296001521819254?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-07&check_out=2024-04-12&source_impression_id=p3_1711642081_ez1PxyG3YOhY7YuJ&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Salamanca',
#   'header': 'Nuevo loft - precio promoción - Vishuddha',
#   'rating_n_reviews': '4,45 (20)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/952118145352980010?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-12&check_out=2024-05-17&source_impression_id=p3_1711642081_JVc%2Fk5MpPV9%2FdVfN&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Tetuán',
#   'header': 'Acogedor piso en el centro de Madrid.',
#   'rating_n_reviews': '4,46 (57)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/857891773095656116?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-12-04&check_out=2024-12-09&source_impression_id=p3_1711642081_nnxj0rcHFiAio%2FLk&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Acogedor y luminoso en el corazón de Madrid',
#   'rating_n_reviews': 'empty',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/930407735064582872?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-16&check_out=2024-06-21&source_impression_id=p3_1711642081_z4UUjMKH4LV9nUGi&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Encantadora buhardillaReinaSofía',
#   'rating_n_reviews': '3,98 (45)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/40885775?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=931746813&check_in=2024-04-29&check_out=2024-05-04&source_impression_id=p3_1711642081_DhYWNdSv9r%2BGvVH3&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Habitación en Centro Madrid',
#   'header': 'Habitación en centro de Madrid',
#   'rating_n_reviews': '4,52 (54)',
#   'price': 'Quédate con Saul',
#   'superhost': 'Quédate con Saul'},
#  {'url': '/rooms/1102155686095438299?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-28&check_out=2024-08-02&source_impression_id=p3_1711642081_V0i3sd3DUOCOgZcN&previous_page_section_name=1000&federated_search_id=58d2f2f2-f48d-4aeb-b5fc-14f07bd85a4c',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Nuevo apartamento+patio Chueca Zerolo GVia',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/41451993?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-02&check_out=2024-04-09&source_impression_id=p3_1711642082_i50TEMwlxviOWZ19&previous_page_section_name=1000&federated_search_id=40f39c44-9401-43fb-9bc1-705296a33c67',
#   'name': 'Loft en Tres Cantos',
#   'header': 'LA oficina 2020',
#   'rating_n_reviews': '4,97 (31)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/864488?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-08-07&check_out=2024-08-12&source_impression_id=p3_1711642082_eqnLRkM8eRjVvmVl&previous_page_section_name=1000&federated_search_id=40f39c44-9401-43fb-9bc1-705296a33c67',
#   'name': 'Apartamento en Madrid',
#   'header': 'Tu pequeño refugio',
#   'rating_n_reviews': '4,72 (485)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/20129330?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1141643852&check_in=2024-04-04&check_out=2024-04-11&source_impression_id=p3_1711642082_76VGV6ztnos8dqll&previous_page_section_name=1000&federated_search_id=40f39c44-9401-43fb-9bc1-705296a33c67',
#   'name': 'Habitación en Madrid',
#   'header': 'Acogedora habitacion Parque El Retiro',
#   'rating_n_reviews': '4,83 (109)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Quédate con Betty'},
#  {'url': '/rooms/888983478371355811?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-02&check_out=2024-06-07&source_impression_id=p3_1711642082_Jh6KwYK8ddwbhlbx&previous_page_section_name=1000&federated_search_id=40f39c44-9401-43fb-9bc1-705296a33c67',
#   'name': 'Apartamento en Madrid',
#   'header': 'Confort y espacio en el corazón de Madrid',
#   'rating_n_reviews': '5,0 (12)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/860130438970182683?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1618826736&check_in=2024-04-14&check_out=2024-04-19&source_impression_id=p3_1711642082_rPSzuCOoC8kauOwN&previous_page_section_name=1000&federated_search_id=40f39c44-9401-43fb-9bc1-705296a33c67',
#   'name': 'Habitación en Madrid',
#   'header': 'Habitación en Madrid Río',
#   'rating_n_reviews': '4,9 (40)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Quédate con Natalia'},
#  {'url': '/rooms/1052296001521819254?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-07&check_out=2024-04-12&source_impression_id=p3_1711642082_odrE6cKY0bJLxU8b&previous_page_section_name=1000&federated_search_id=40f39c44-9401-43fb-9bc1-705296a33c67',
#   'name': 'Apartamento en Madrid',
#   'header': 'Nuevo loft - precio promoción - Vishuddha',
#   'rating_n_reviews': '4,45 (20)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/3397465?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-16&check_out=2024-07-21&source_impression_id=p3_1711642082_i%2F%2FUUBFJkzA%2FGlLq&previous_page_section_name=1000&federated_search_id=40f39c44-9401-43fb-9bc1-705296a33c67',
#   'name': 'Apartamento en Madrid',
#   'header': 'Apartamento junto Gran Vía',
#   'rating_n_reviews': '4,89 (888)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
# ...
#   'name': 'Apartamento en Tetuán',
#   'header': 'Estudio en Madrid',
#   'rating_n_reviews': '4,25 (8)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/812230543574427251?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1573709733&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642093_e2RKKsKghevdNS2N&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Habitación en Centro Madrid',
#   'header': 'L ) Habitación  sin ventana. / Leer descripción.',
#   'rating_n_reviews': '4,79 (61)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Quédate con Raul'},
#  {'url': '/rooms/459303?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642093_kBQkg7jK1o9YAslp&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'GRAN VIA - l - CÉNTRICO & LUMINOSO',
#   'rating_n_reviews': '4,54 (96)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/678760934114887406?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-12&check_out=2024-05-17&source_impression_id=p3_1711642093_vbAg%2BfYxr7fTHLy%2F&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'NEW APT: PUERTA DE ALCALA-RETIRO PARK-GRAN VIA !!!',
#   'rating_n_reviews': '4,69 (65)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/53714783?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-29&check_out=2024-08-03&source_impression_id=p3_1711642093_kEozAJxV0DVA82nq&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Espectaculares vistas con 2 terrazas en Gran Vía',
#   'rating_n_reviews': '4,89 (87)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/51008640?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-21&check_out=2024-04-26&source_impression_id=p3_1711642093_LtOKyDBzLPOFS4iw&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Luminosa suite en Almagro, Madrid',
#   'rating_n_reviews': '4,43 (72)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/1008475453323219980?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-10-27&check_out=2024-11-01&source_impression_id=p3_1711642093_T1vi7N8hKAFBmOfJ&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Apartamento bohemio chic',
#   'rating_n_reviews': '4,67 (27)',
#   'price': 'Superanfitrión',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/830938597120163666?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1614958649&check_in=2024-11-04&check_out=2024-11-09&source_impression_id=p3_1711642093_PfrBxDNAaiALkBcH&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Habitación en Ciudad Lineal',
#   'header': 'Habitación para mujeres',
#   'rating_n_reviews': '4,91 (34)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Quédate con Farida'},
#  {'url': '/rooms/1075980010565038509?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-19&check_out=2024-05-24&source_impression_id=p3_1711642093_Ubju0Uj15f3ZVqk2&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Apartamento de Lujo en Gran via',
#   'rating_n_reviews': '4,25 (4)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/892598040026096665?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-05&check_out=2024-04-10&source_impression_id=p3_1711642093_tWAY5AC2y7ujYyFs&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Apartamento en Ibiza',
#   'header': 'Bonito estudio en el Barrio de Ibiza.',
#   'rating_n_reviews': '4,55 (20)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/643921823471483623?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-08-17&check_out=2024-08-22&source_impression_id=p3_1711642093_8%2F%2B1gr6cvhcaGXie&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Apartamento en Centro Madrid',
#   'header': '¡La mejor ubicación! 2 dormitorios. Wifi. Camas tamaño queen.',
#   'rating_n_reviews': '4,53 (136)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/22598667?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-29&check_out=2024-08-03&source_impression_id=p3_1711642093_UWRDn0tFTGOTxk4n&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Plaza Mayor - 5 minutos andando',
#   'rating_n_reviews': '4,7 (395)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/1087517470686844294?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-28&check_out=2024-05-03&source_impression_id=p3_1711642093_iSPjxrV1uG%2FY1bzP&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Apartamento en Tetuán',
#   'header': 'Parking Gratis - Nuevo, moderno y acogedor',
#   'rating_n_reviews': '5,0 (3)',
#   'price': 'Superanfitrión',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/44697269?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-02&check_out=2024-06-07&source_impression_id=p3_1711642093_DvlG%2B6tE7wY65eoK&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Bed\xa0and\xa0breakfast en Centro Madrid',
#   'header': 'Habitación doble',
#   'rating_n_reviews': '4,82 (476)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/39739171?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-04&check_out=2024-04-09&source_impression_id=p3_1711642093_k3KR9NLNj1Ifxgt4&previous_page_section_name=1000&federated_search_id=5048479c-4aa5-4cc8-bbf5-de5831b2ab46',
#   'name': 'Apartamento en Hortaleza',
#   'header': 'Ifema Aeropuerto',
#   'rating_n_reviews': '4,81 (78)',
#   'price': 'Superanfitrión',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/35121463?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-12&check_out=2024-05-17&source_impression_id=p3_1711642094_HDLHgLslniKVBAnR&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Tetuán',
#   'header': 'Parking Gratis - Super ubicación, luminoso, 1hab',
#   'rating_n_reviews': '4,87 (281)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/1120068677320792245?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642094_TDAbOgH6hGDbFV5V&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Chamartín',
#   'header': '18 Beautiful Costa Rica Apartment Madrid',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/804098779168912342?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-04&check_out=2024-05-11&source_impression_id=p3_1711642094_99w5TkfTij0tXbRN&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Bonito estudio en el corazón de Madrid -Atocha',
#   'rating_n_reviews': '4,31 (16)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/997467791628376513?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-02&check_out=2024-04-07&source_impression_id=p3_1711642094_b5iLYqZARHioXwK4&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Tetuán',
#   'header': 'Estudio cerca del ascensor del estadio Bernabéu + wifi de alta velocidad',
#   'rating_n_reviews': '4,63 (16)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/933326?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-24&check_out=2024-06-29&source_impression_id=p3_1711642094_OH%2F97YhOlSShD0Kx&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Atocha',
#   'header': 'Agradable piso con ubicación céntrica en Atocha',
#   'rating_n_reviews': '4,67 (107)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/1120905234587456836?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642094_Si7O%2B9P9%2BjkycoB8&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Alojamiento en Hortaleza',
#   'header': 'Acogedora habitación privada con baño cerca del aeropuerto de Madrid',
#   'rating_n_reviews': 'Nuevo',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/30755714?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-27&check_out=2024-05-02&source_impression_id=p3_1711642094_DcETljaJcZF4GGs6&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Habitación de hotel en Ciudad Lineal',
#   'header': 'Habitación de lo mas acojedora y cómoda en Madrid',
#   'rating_n_reviews': '4,75 (207)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/19280280?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-21&check_out=2024-07-26&source_impression_id=p3_1711642094_9tS8%2BFlYie9eieQb&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Best Location 2BD, 2BTH! WIFI. Puerta del Sol',
#   'rating_n_reviews': '4,36 (358)',
#   'price': 'Anfitrión profesional',
#   'superhost': 'Anfitrión profesional'},
#  {'url': '/rooms/103541?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-19&check_out=2024-05-24&source_impression_id=p3_1711642094_iJbfVag3i%2BKVyncv&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Chamberí',
#   'header': 'CENTRAL Y CÓMODA APTO. W/PARKING',
#   'rating_n_reviews': '4,6 (291)',
#   'price': 'Superanfitrión',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/4295344?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-01&check_out=2024-04-06&source_impression_id=p3_1711642094_CpgGEKiojqhQY6co&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Loft en Centro Madrid',
#   'header': 'Estudio Ideal en el Corazón del Arte (2do D)',
#   'rating_n_reviews': '4,76 (643)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/11753638?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-28&check_out=2024-08-02&source_impression_id=p3_1711642094_JXooMYMyRunCldzH&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Moncloa - Argüelles',
#   'header': 'Céntrico y equipado apartamento',
#   'rating_n_reviews': '4,55 (437)',
#   'price': 'Superanfitrión',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/3727205?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-08-11&check_out=2024-08-16&source_impression_id=p3_1711642094_cOfH8iS70uDxATpj&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Piso de ensueño  en Malasaña!',
#   'rating_n_reviews': '4,74 (748)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/48672492?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-09-01&check_out=2024-09-06&source_impression_id=p3_1711642094_ZBGN8TwiAVO%2FJdtF&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Chamartín',
#   'header': 'Estudio/Suite/con independencia.',
#   'rating_n_reviews': '4,91 (90)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/5285533?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-07-07&check_out=2024-07-12&source_impression_id=p3_1711642094_w2hWFJraalfAu6D7&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Apartament entre P. Real y Gran Via',
#   'rating_n_reviews': '4,83 (174)',
#   'price': 'Recomendación del viajero',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/1090694911446906109?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-05-12&check_out=2024-05-17&source_impression_id=p3_1711642094_cLQaNBXLQGRNWVba&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Super Loft Malasaña Gran Via',
#   'rating_n_reviews': '4,67 (3)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/846426208549575549?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-04-07&check_out=2024-04-12&source_impression_id=p3_1711642094_wdCZk4pFB979%2FlbR&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Suite con entrada independiente en Centro Madrid',
#   'header': 'diseñado, arte y vista en la latina',
#   'rating_n_reviews': '4,81 (54)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/771551626281396323?adults=1&children=0&enable_m3_private_room=true&infants=0&pets=0&check_in=2024-06-16&check_out=2024-06-21&source_impression_id=p3_1711642094_WbUmWlG1RWfUBCjA&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Apartamento en Centro Madrid',
#   'header': 'Maravilloso piso estudio',
#   'rating_n_reviews': '4,64 (118)',
#   'price': 'Anfitrión particular',
#   'superhost': 'Anfitrión particular'},
#  {'url': '/rooms/710833885935929341?adults=1&category_tag=Tag%3A8678&children=0&enable_m3_private_room=true&infants=0&pets=0&photo_id=1486082485&check_in=2024-04-04&check_out=2024-04-09&source_impression_id=p3_1711642094_1AgdYungo9v31U6V&previous_page_section_name=1000&federated_search_id=1687c3af-b028-4975-a940-db0645398fc3',
#   'name': 'Habitación en Centro Madrid',
#   'header': 'Pequeña habitación privada',
#   'rating_n_reviews': '4,7 (122)',
#   'price': 'Quédate con Cristina',
#   'superhost': 'Quédate con Cristina'}]

# %%
df = pd.DataFrame(base_features)
df
# Out:
#                                                    url  \
# 0    /rooms/46416127?adults=1&children=0&enable_m3_...
# 1    /rooms/1120220796513899602?adults=1&children=0...
# 2    /rooms/1019679548854540460?adults=1&children=0...
# 3    /rooms/1120093500114698390?adults=1&children=0...
# 4    /rooms/1119750870732308638?adults=1&children=0...
# ..                                                 ...
# 265  /rooms/5285533?adults=1&children=0&enable_m3_p...
# 266  /rooms/1090694911446906109?adults=1&children=0...
# 267  /rooms/846426208549575549?adults=1&children=0&...
# 268  /rooms/771551626281396323?adults=1&children=0&...
# 269  /rooms/710833885935929341?adults=1&category_ta...
#
#                                                  name  \
# 0              Habitación compartida en Centro Madrid
# 1                        Apartamento en Centro Madrid
# 2                        Alojamiento en Centro Madrid
# 3                        Apartamento en Centro Madrid
# 4                        Apartamento en Centro Madrid
# ..                                                ...
# 265                      Apartamento en Centro Madrid
# 266                      Apartamento en Centro Madrid
# 267  Suite con entrada independiente en Centro Madrid
# 268                      Apartamento en Centro Madrid
# 269                       Habitación en Centro Madrid
#
#                                              header rating_n_reviews  \
# 0    Madrid Centro: Puerta del Sol, Tirso de Molina        4,95 (83)
# 1         Alojamiento entero en el centro de Madrid            Nuevo
# 2                   Habitación céntrica en Chamberí        4,74 (23)
# 3                 GuestReady - Madrid Urban Retreat            Nuevo
# 4                                Patio de La Latina            Nuevo
# ..                                              ...              ...
# 265             Apartament entre P. Real y Gran Via       4,83 (174)
# 266                    Super Loft Malasaña Gran Via         4,67 (3)
# 267             diseñado, arte y vista en la latina        4,81 (54)
# 268                        Maravilloso piso estudio       4,64 (118)
# 269                      Pequeña habitación privada        4,7 (122)
#
#                          price              superhost
# 0    Recomendación del viajero  Anfitrión profesional
# 1         Anfitrión particular   Anfitrión particular
# 2         Anfitrión particular   Anfitrión particular
# 3              3 camas «queen»        3 camas «queen»
# 4         Anfitrión particular   Anfitrión particular
# ..                         ...                    ...
# 265  Recomendación del viajero   Anfitrión particular
# 266       Anfitrión particular   Anfitrión particular
# 267       Anfitrión particular   Anfitrión particular
# 268       Anfitrión particular   Anfitrión particular
# 269       Quédate con Cristina   Quédate con Cristina
#
# [270 rows x 6 columns]

# %%
df['ciudad'] = df['name'].str.replace('Villa en |Cueva en |Vivienda en |Apartamento en |Habitación en |Loft en ', '', regex=True)
df
# Out:
#                                                    url  \
# 0    /rooms/46416127?adults=1&children=0&enable_m3_...
# 1    /rooms/1120220796513899602?adults=1&children=0...
# 2    /rooms/1019679548854540460?adults=1&children=0...
# 3    /rooms/1120093500114698390?adults=1&children=0...
# 4    /rooms/1119750870732308638?adults=1&children=0...
# ..                                                 ...
# 265  /rooms/5285533?adults=1&children=0&enable_m3_p...
# 266  /rooms/1090694911446906109?adults=1&children=0...
# 267  /rooms/846426208549575549?adults=1&children=0&...
# 268  /rooms/771551626281396323?adults=1&children=0&...
# 269  /rooms/710833885935929341?adults=1&category_ta...
#
#                                                  name  \
# 0              Habitación compartida en Centro Madrid
# 1                        Apartamento en Centro Madrid
# 2                        Alojamiento en Centro Madrid
# 3                        Apartamento en Centro Madrid
# 4                        Apartamento en Centro Madrid
# ..                                                ...
# 265                      Apartamento en Centro Madrid
# 266                      Apartamento en Centro Madrid
# 267  Suite con entrada independiente en Centro Madrid
# 268                      Apartamento en Centro Madrid
# 269                       Habitación en Centro Madrid
#
#                                              header rating_n_reviews  \
# 0    Madrid Centro: Puerta del Sol, Tirso de Molina        4,95 (83)
# 1         Alojamiento entero en el centro de Madrid            Nuevo
# 2                   Habitación céntrica en Chamberí        4,74 (23)
# 3                 GuestReady - Madrid Urban Retreat            Nuevo
# 4                                Patio de La Latina            Nuevo
# ..                                              ...              ...
# 265             Apartament entre P. Real y Gran Via       4,83 (174)
# 266                    Super Loft Malasaña Gran Via         4,67 (3)
# 267             diseñado, arte y vista en la latina        4,81 (54)
# 268                        Maravilloso piso estudio       4,64 (118)
# 269                      Pequeña habitación privada        4,7 (122)
#
#                          price              superhost  \
# 0    Recomendación del viajero  Anfitrión profesional
# 1         Anfitrión particular   Anfitrión particular
# 2         Anfitrión particular   Anfitrión particular
# 3              3 camas «queen»        3 camas «queen»
# 4         Anfitrión particular   Anfitrión particular
# ..                         ...                    ...
# 265  Recomendación del viajero   Anfitrión particular
# 266       Anfitrión particular   Anfitrión particular
# 267       Anfitrión particular   Anfitrión particular
# 268       Anfitrión particular   Anfitrión particular
# 269       Quédate con Cristina   Quédate con Cristina
#
#                                                ciudad
# 0              Habitación compartida en Centro Madrid
# 1                                       Centro Madrid
# 2                        Alojamiento en Centro Madrid
# 3                                       Centro Madrid
# 4                                       Centro Madrid
# ..                                                ...
# 265                                     Centro Madrid
# 266                                     Centro Madrid
# 267  Suite con entrada independiente en Centro Madrid
# 268                                     Centro Madrid
# 269                                     Centro Madrid
#
# [270 rows x 7 columns]

# %%
ruta = 'Alojamientos_Madrid_Airbnb.csv'
df.to_csv(ruta,index=False)
